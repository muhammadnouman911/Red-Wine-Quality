# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../red_wine_quality.csv')
df.head()
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

regresor=RandomForestRegressor(n_estimators=900, random_state=0)

regresor.fit(X_train,Y_train)
Y_pred = regresor.predict(X_test)

# %%
print(Y_test.shape, Y_pred.shape)
# Out:
# (320,) (320,)

# %% [markdown]
# # Accuracy Check

# %%
from sklearn.metrics import r2_score
r2=r2_score(Y_test,Y_pred)
print(r2)

# %%
import statsmodels.api as sm
regressor_ols = sm.OLS(endog=Y_train, exog=X_train).fit()
regressor_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                quality   R-squared (uncentered):                   0.987
# Model:                            OLS   Adj. R-squared (uncentered):              0.987
# Method:                 Least Squares   F-statistic:                              8683.
# Date:                Fri, 19 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        14:52:52   Log-Likelihood:                         -1269.9
# No. Observations:                1279   AIC:                                      2562.
# Df Residuals:                    1268   BIC:                                      2619.
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# fixed acidity            0.0084      0.019      0.451      0.652      -0.028       0.045
# volatile acidity        -1.1766      0.132     -8.916      0.000      -1.435      -0.918
# citric acid             -0.1794      0.165     -1.085      0.278      -0.504       0.145
# residual sugar           0.0131      0.013      0.984      0.325      -0.013       0.039
# chlorides               -1.9370      0.464     -4.177      0.000      -2.847      -1.027
# free sulfur dioxide      0.0030      0.002      1.242      0.214      -0.002       0.008
# total sulfur dioxide    -0.0029      0.001     -3.587      0.000      -0.004      -0.001
# density                  4.1918      0.707      5.928      0.000       2.805       5.579
# pH                      -0.4276      0.181     -2.364      0.018      -0.783      -0.073
# sulphates                0.8747      0.121      7.230      0.000       0.637       1.112
# alcohol                  0.3007      0.019     15.473      0.000       0.263       0.339
# ==============================================================================
# Omnibus:                       18.054   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.349
# Skew:                          -0.166   Prob(JB):                     5.16e-06
# Kurtosis:                       3.589   Cond. No.                     2.50e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
